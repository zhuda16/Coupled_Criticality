# %% [markdown]
# # Figure 3B–E
#
# Reproduce only the finalized quantitative panels for 20 networks and six signals. Panel C uses network 17; panel D bands are mean ± SD across networks.

# %%
from pathlib import Path
import sys
here = Path.cwd().resolve()
root = next(p for p in [here, *here.parents] if (p / 'data').is_dir() and (p / 'programe').is_dir())
sys.path.insert(0, str(root / 'programe'))
from figure3_demo import build_figure

# %%
fig = build_figure()
fig

# %% [markdown]
# Run `python programe/figure3_demo.py` from the repository root to export PNG, PDF and SVG files to `output/`.
